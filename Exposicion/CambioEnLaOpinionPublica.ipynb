# %%
import numpy as np
import matplotlib.pyplot as plt

# Definir la función f(t) = 20 * exp(-0.1 * t)
def f(t):
    return 20 * np.exp(-0.1 * t)

# Crear un arreglo de días t (de 0 a 30)
t_values = np.linspace(0, 30, 100)

# Calcular las tasas de cambio f(t) para cada valor de t
f_values = f(t_values)

# Calcular el apoyo acumulado (integral numérica usando el método de integración trapezoidal)
apoyo_acumulado = np.cumsum(f_values) * (t_values[1] - t_values[0])  # Aproximación numérica

# Imprimir el apoyo acumulado en el día 30
print(f"Apoyo acumulado en 30 días: {apoyo_acumulado[-1]:.2f}")

# Graficar la tasa de cambio y el apoyo acumulado
plt.figure(figsize=(10, 6))

# Graficar la tasa de cambio f(t)
plt.subplot(2, 1, 1)
plt.plot(t_values, f_values, label="Tasa de cambio f(t)", color='blue')
plt.title("Tasa de Cambio de Apoyo en Función del Tiempo")
plt.xlabel("Día (t)")
plt.ylabel("Tasa de cambio f(t)")
plt.grid(True)
plt.legend()

# Graficar el apoyo acumulado
plt.subplot(2, 1, 2)
plt.plot(t_values, apoyo_acumulado, label="Apoyo acumulado", color='green')
plt.title("Apoyo Acumulado en Función del Tiempo")
plt.xlabel("Día (t)")
plt.ylabel("Apoyo acumulado")
plt.grid(True)
plt.legend()

# Mostrar las gráficas
plt.tight_layout()
plt.show()
# Out:
# Apoyo acumulado en 30 días: 193.24
